# %% [markdown]
# # Problem Statement

# %% [markdown]
# Every year a lot of companies hire a number of employees. The companies invest time and money in training those employees, not just this but there are training programs within the companies for their existing employees as well. The aim of these programs is to increase the effectiveness of their employees. But where HR Analytics fit in this? and is it just about improving the performance of employees?

# %% [markdown]
# #### HR Analytics

# %% [markdown]
# Human resource analytics (HR analytics) is an area in the field of analytics that refers to applying analytic processes to the human resource department of an organization in the hope of improving employee performance and therefore getting a better return on investment. HR analytics does not just deal with gathering data on employee efficiency. Instead, it aims to provide insight into each process by gathering data and then using it to make relevant decisions about how to improve these processes.

# %% [markdown]
# #### Attrition in HR

# %% [markdown]
# Attrition in human resources refers to the gradual loss of employees overtime. In general, relatively high attrition is problematic for companies. HR professionals often assume a leadership role in designing company compensation programs, work culture, and motivation systems that help the organization retain top employees.

# %% [markdown]
# ### Attrition affecting Companies

# %% [markdown]
# A major problem in high employee attrition is its cost to an organization. Job postings, hiring processes, paperwork, and new hire training are some of the common expenses of losing employees and replacing them. Additionally, regular employee turnover prohibits your organization from increasing its collective knowledge base and experience over time. This is especially concerning if your business is customer-facing, as customers often prefer to interact with familiar people. Errors and issues are more likely if you constantly have new workers.

# %%
#Importing Necessary Libraries
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %% [markdown]
# The Shape of the Dataset is 1470, 35.
#
# That means there are 1470 Employee Data available and 35 different attributes.

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# There are no Null values present in the Dataset

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
#Importing Visualization Libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Ckecking Null Values Using Heatmap
plt.figure(figsize=(15,10))
plt.title('Null Values')
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:title={'center':'Null Values'}>

# %% [markdown]
# No Null Values are present

# %% [markdown]
# ### Statistical Summery

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# We can observe that for most of attribute the median values(50%) is near to it's mean value which shows that data is normally distributed.
#
# In some columns such as Employeecount, StandardHours only single number is repeated.Which means these attributes has no significance.

# %% [markdown]
# ### Separte Categorical Attributes/Columns

# %%
df_obj=df.select_dtypes(include='object')

# %%
df_obj
# Out:
#      Attrition     BusinessTravel              Department EducationField  \
# 0          Yes      Travel_Rarely                   Sales  Life Sciences
# 1           No  Travel_Frequently  Research & Development  Life Sciences
# 2          Yes      Travel_Rarely  Research & Development          Other
# 3           No  Travel_Frequently  Research & Development  Life Sciences
# 4           No      Travel_Rarely  Research & Development        Medical
# ...        ...                ...                     ...            ...
# 1465        No  Travel_Frequently  Research & Development        Medical
# 1466        No      Travel_Rarely  Research & Development        Medical
# 1467        No      Travel_Rarely  Research & Development  Life Sciences
# 1468        No  Travel_Frequently                   Sales        Medical
# 1469        No      Travel_Rarely  Research & Development        Medical
#
#       Gender                    JobRole MaritalStatus Over18 OverTime
# ...

# %%
for col in df_obj:
    print('\n')
    print(df[col].value_counts())
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64
#
#
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
#
#
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
#
#
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64
#
#
# Male      882
# Female    588
# Name: Gender, dtype: int64
#
#
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64
#
#
# Married     673
# Single      470
# Divorced    327
# ...

# %% [markdown]
# Over18 attribute has only one category. we can drop it.
#
# We can see that our Target attribute is imbalanced.

# %% [markdown]
# #### Univariate Analysis

# %%
plt.figure(figsize=(10,6))
plt.title('Target Data Distribution')
sns.countplot(df['Attrition'],data=df)
plt.show()

# %% [markdown]
# We can see that the dataset is Imbalanced

# %% [markdown]
# #### Bivariate Analysis

# %%
plt.figure(figsize=(12,8))
plt.title('MaritalStatus vs Attrition Relation')
sns.countplot(df['MaritalStatus'],hue='Attrition',data=df)
# Out:
# <AxesSubplot:title={'center':'MaritalStatus vs Attrition Relation'}, xlabel='MaritalStatus', ylabel='count'>

# %% [markdown]
# We can see that, unmarried people have higher tendency to leave the company as comapired to Married or Divorced.
#
# Divorced has lowest chanaces to left the company.

# %%
plt.figure(figsize=(12,8))
plt.title('Overtime vs Attrition Relation')
sns.countplot(df['OverTime'],hue='Attrition',data=df)
# Out:
# <AxesSubplot:title={'center':'Overtime vs Attrition Relation'}, xlabel='OverTime', ylabel='count'>

# %% [markdown]
# People who do most overtime leave the Company

# %%
plt.figure(figsize=(10,6))
plt.xticks(rotation=45)
plt.title('Job Role vs Attrition')
sns.countplot(df['JobRole'],hue='Attrition',data=df)
# Out:
# <AxesSubplot:title={'center':'Job Role vs Attrition'}, xlabel='JobRole', ylabel='count'>

# %% [markdown]
# Sales Executive,Laboratory Technician, Sales representatives research scientis have higher tendency to leave jo

# %%
plt.figure(figsize=(12,10))
plt.title('Sex vs Attrition')
sns.countplot(df['Gender'],data=df[df['Attrition']=='Yes'])
# Out:
# <AxesSubplot:title={'center':'Sex vs Attrition'}, xlabel='Gender', ylabel='count'>

# %% [markdown]
# We can observe from above table that male has higher chances to change job as compaired to Female.

# %%
plt.figure(figsize=(12,8))
plt.title('EducationField vs Attrition Relation')
sns.countplot(df['EducationField'],data=df)
# Out:
# <AxesSubplot:title={'center':'EducationField vs Attrition Relation'}, xlabel='EducationField', ylabel='count'>

# %% [markdown]
# We can see that life science and Medical two major Education fields which has higher demand in market and people are switch their job more frequent.

# %%
plt.figure(figsize=(12,8))
plt.title('Department vs Attrition',fontsize=15)
sns.countplot(df['Department'],data=df[df['Attrition']=='Yes'])
# Out:
# <AxesSubplot:title={'center':'Department vs Attrition'}, xlabel='Department', ylabel='count'>

# %% [markdown]
# We can see that people who works in Research & development have higher chances to leave the company.
# HR department people have least chances to job change.

# %%
plt.figure(figsize=(15,8))
plt.title('BusinessTravel vs Attrition')
sns.countplot(df['BusinessTravel'],hue='Attrition',data=df)
# Out:
# <AxesSubplot:title={'center':'BusinessTravel vs Attrition'}, xlabel='BusinessTravel', ylabel='count'>

# %%
plt.figure(figsize=(15,8))
plt.title('Age effect on Attrition')
sns.countplot(df['Age'],data=df[df['Attrition']=='Yes'])
# Out:
# <AxesSubplot:title={'center':'Age effect on Attrition'}, xlabel='Age', ylabel='count'>

# %% [markdown]
# 29-40 Age group people are lilely to chnage job

# %%
plt.figure(figsize=(12,8))
plt.title('JobSatisfaction on Attrition')
sns.countplot(df['JobSatisfaction'],data=df)
# Out:
# <AxesSubplot:title={'center':'JobSatisfaction on Attrition'}, xlabel='JobSatisfaction', ylabel='count'>

# %% [markdown]
# We can see that an employee with 3 or 4 job satisfaction grade has higher chance to left company.

# %%
plt.figure(figsize=(12,8))
plt.title('Last Promotion  vs Attrition')
sns.countplot(df['YearsSinceLastPromotion'],hue='Attrition',data=df)
# Out:
# <AxesSubplot:title={'center':'Last Promotion  vs Attrition'}, xlabel='YearsSinceLastPromotion', ylabel='count'>

# %% [markdown]
# Employee who did not get promtion for 1-2 years also have a good chances for job change.

# %%
plt.figure(figsize=(12,8))
plt.title('JobLevel vs Attrition')
sns.countplot(df['JobLevel'],hue='Attrition',data=df)
# Out:
# <AxesSubplot:title={'center':'JobLevel vs Attrition'}, xlabel='JobLevel', ylabel='count'>

# %% [markdown]
# We can see employee who has job band/level 1 has tendency to change job more frequent then job level 4 or 5.

# %%
plt.figure(figsize=(15,8))
plt.title('Num Companies Worked vs Attrition')
sns.countplot(df['NumCompaniesWorked'],hue='Attrition',data=df)
# Out:
# <AxesSubplot:title={'center':'Num Companies Worked vs Attrition'}, xlabel='NumCompaniesWorked', ylabel='count'>

# %% [markdown]
# We have drop EmployeeCount,StandardHours because it has only one unique values.
# We have drop EmployeeCount,EmployeeNumber because it is just a counting number of employees , it has no significance for checking Attrition.

# %% [markdown]
# Most of our data is Normally distributed.
# Attributes like Total working years,Yearsatcompany, Years since last promotion etc. are right skewed.
# This shows some outliers must be present in our dataset.
# We will remove skewness by some trasformation methods.

# %%
## Dropping the duplicate columns
df_1=df.drop(['EmployeeCount','StandardHours','EmployeeNumber'],axis=1)

# %% [markdown]
# ## Distribution of Data

# %%
df_new=df_1.select_dtypes(exclude='object')
plt.figure(figsize=(18,15))
plot=1
for col in df_new:
    if plot<=25:
        plt.subplot(5,5,plot)
        sns.distplot(df_1[col])
        plt.xlabel(col)
        plot=plot+1
plt.show()

# %% [markdown]
# Most of our data is Normally distributed.
# Attributes like Total working years,Yearsatcompany, Years since last promotion etc. are right skewed.
# This shows some outliers must be present in our dataset.
# We will remove skewness by some trasformation methods.

# %% [markdown]
# ## Checking Outliers

# %%
plt.figure(figsize=(18,15))
plot=1
for col in df_new:
    if plot<=25:
        plt.subplot(5,5,plot)
        sns.boxplot(df_1[col])
        plt.xlabel(col)
        plot=plot+1
plt.show()

# %% [markdown]
# Outliers Present in Many columns

# %%
#Removing Outliers
from scipy.stats import zscore
z =np.abs(zscore(df_new))
print(z.shape)
df_1 = df_1.loc[(z<3).all(axis=1)]
print(df_1.shape)
# Out:
# (1470, 23)
# (1387, 32)

# %% [markdown]
# ## Checking Skewness

# %%
df_1.skew()
# Out:
# Age                         0.472280
# DailyRate                  -0.017078
# DistanceFromHome            0.954752
# Education                  -0.289024
# EnvironmentSatisfaction    -0.325285
# HourlyRate                 -0.030481
# JobInvolvement             -0.501401
# JobLevel                    1.126075
# JobSatisfaction            -0.345612
# MonthlyIncome               1.544770
# MonthlyRate                 0.030596
# NumCompaniesWorked          1.037715
# PercentSalaryHike           0.800592
# PerformanceRating           1.931566
# RelationshipSatisfaction   -0.295686
# StockOptionLevel            0.962332
# TotalWorkingYears           1.034487
# TrainingTimesLastYear       0.577614
# WorkLifeBalance            -0.557100
# YearsAtCompany              1.248623
# YearsInCurrentRole          0.726675
# YearsSinceLastPromotion     1.756335
# YearsWithCurrManager        0.694506
# dtype: float64

# %% [markdown]
# We can see that Skewness is present in Most Columns

# %%
#Removing Skewness
for i in df_new:
    if df_1[i].skew()>.55:
        df_1[i]=np.log1p(df_1[i])

# %%
df_1.skew()
# Out:
# Age                         0.472280
# DailyRate                  -0.017078
# DistanceFromHome           -0.031570
# Education                  -0.289024
# EnvironmentSatisfaction    -0.325285
# HourlyRate                 -0.030481
# JobInvolvement             -0.501401
# JobLevel                    0.497167
# JobSatisfaction            -0.345612
# MonthlyIncome               0.318873
# MonthlyRate                 0.030596
# NumCompaniesWorked          0.101288
# PercentSalaryHike           0.496106
# PerformanceRating           1.931566
# RelationshipSatisfaction   -0.295686
# StockOptionLevel            0.275912
# TotalWorkingYears          -0.728348
# TrainingTimesLastYear      -1.044321
# WorkLifeBalance            -0.557100
# YearsAtCompany             -0.379527
# YearsInCurrentRole         -0.390406
# YearsSinceLastPromotion     0.248883
# YearsWithCurrManager       -0.347018
# dtype: float64

# %% [markdown]
# Skewness Removed From Max Columns

# %% [markdown]
# ## Encoding of Column

# %%
#Importing Necessary Libraries
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for col in df_obj:
    df_1[col]=le.fit_transform(df_1[col])

# %%
#Checking New Dataset
df_1.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2          0.693147
# 1   49          0               1        279           1          2.197225
# 2   37          1               2       1373           1          1.098612
# 3   33          0               1       1392           1          1.386294
# 4   27          0               2        591           1          1.098612
#
#    Education  EducationField  EnvironmentSatisfaction  Gender  ...  \
# 0          2               1                        2       0  ...
# 1          1               1                        3       1  ...
# 2          2               4                        4       1  ...
# 3          4               1                        4       0  ...
# 4          1               3                        1       1  ...
#
#    PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %% [markdown]
# ## Splitting the Data into Input and Target Variable

# %%
x=df_1.drop(['Attrition','Over18'],axis=1)
y=df_1[['Attrition']]

# %% [markdown]
# Over18 has no effect on Output.So we dropprd it.

# %% [markdown]
# ## Scaling the Input Data

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_scaled=sc.fit_transform(x)
x=pd.DataFrame(x_scaled,columns=x.columns)
x
# Out:
#            Age  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0     0.536681        0.593126   0.734325    1.405373         -1.502086
# 1     1.442111       -0.905354  -1.307769   -0.496337          0.253886
# 2     0.083966        0.593126   1.406752   -0.496337         -1.028716
# 3    -0.368749       -0.905354   1.453896   -0.496337         -0.692855
# 4    -1.047821        0.593126  -0.533609   -0.496337         -1.028716
# ...        ...             ...        ...         ...               ...
# 1382 -0.029213       -0.905354   0.193406   -0.496337          1.398978
# 1383  0.310324        0.593126  -0.479021   -0.496337         -0.039518
# 1384 -1.047821        0.593126  -1.615447   -0.496337         -0.432340
# 1385  1.442111       -0.905354   0.538304    1.405373         -1.028716
# 1386 -0.255570        0.593126  -0.441802   -0.496337          0.253886
#
#       Education  EducationField  EnvironmentSatisfaction    Gender  \
# ...

# %%
print(x.shape,y.shape)
# Out:
# (1387, 30) (1387, 1)

# %% [markdown]
# ## Checking Feature Importance

# %%
#Importing Libraries
from sklearn.ensemble import ExtraTreesClassifier
extra=ExtraTreesClassifier()
extra.fit(x,y)
print(extra.feature_importances_)
# Out:
# [0.04291711 0.02635548 0.0322499  0.0246533  0.03513443 0.02782891
#  0.02977278 0.03887922 0.02115668 0.03099245 0.03461171 0.03404256
#  0.03132565 0.03501465 0.03368533 0.04372665 0.03080409 0.03330077
#  0.07017892 0.02944835 0.01341462 0.03234004 0.03397514 0.04176507
#  0.02869991 0.03615861 0.03599678 0.03031886 0.02711621 0.03413581]

# %% [markdown]
# ### Plotiing Features using Visualization

# %%
plt.figure(figsize=(10,6))
plt.title('Important Features')
feat_importance=pd.Series(extra.feature_importances_,index=x.columns)
feat_importance.nlargest(10).plot(kind='bar')
plt.show()

# %% [markdown]
# So we can saybthat Overtime, Age, TotalworkingYears are 3 most important attribute which decide Employee will stay or not

# %% [markdown]
# # Predictive Model Building

# %%
#Importing Libraries
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier

from sklearn.ensemble import GradientBoostingClassifier

from sklearn.model_selection import train_test_split,GridSearchCV,cross_val_score
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,roc_auc_score,f1_score,roc_curve,auc

# %% [markdown]
# ### Lets Find the best Random state no for Maximum accuracy

# %%
maxAccu=0
maxRS=0


for i in range (1,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=i)
    lr=LogisticRegression()
    
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
        
print('Best accuracu is',maxAccu,'on Random State',maxRS)
# Out:
# Best accuracu is 0.9106628242074928 on Random State 76

# %% [markdown]
# ### Divide the data into Train and Test

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=76,stratify=y)

print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (1040, 30) (347, 30) (1040, 1) (347, 1)

# %%
lr=LogisticRegression()
dtc=DecisionTreeClassifier()
svc=SVC()
gnb=GaussianNB()
knn=KNeighborsClassifier()
rfc=RandomForestClassifier()
gbc=GradientBoostingClassifier()
adb=AdaBoostClassifier()

# %%
models=[]
models.append(('LogisticRegression',lr))
models.append(('GaussianNB',gnb))
models.append(('RandomForestClassifier',rfc))
models.append(('GradientBoostingClassifier',gbc))
models.append(('KNeighborsClassifier',knn))
models.append(('SVC',svc))
models.append(('DecisionTreeClassifier',dtc))
models.append(('AdaBoostClassifier',adb))

# %%
Model=[]
score=[]
CVS=[]
rocscore=[]
for name,model in models:
    print(name)
    print('\n')
    Model.append(name)
    model.fit(x_train,y_train)
    print(model)
    pre=model.predict(x_test)
    print('\n')
    AS=accuracy_score(y_test,pre)
    print('Accuracy_score=',AS)
    score.append(AS*100)
    print('\n')
    sc=cross_val_score(model,x,y,cv=10,scoring='accuracy').mean()
    print('Cross_Val_Score=',sc)
    CVS.append(sc*100)
    print('\n')
    false_positive_rate,true_positive_rate,threshold=roc_curve(y_test,pre)
    roc_auc= auc(false_positive_rate,true_positive_rate)
    print('roc_auc_score=',roc_auc)
    rocscore.append(roc_auc*100)
    print('\n')
    print('classification_report\n',classification_report(y_test,pre))
    print('\n')
    cm=confusion_matrix(y_test,pre)
    print(cm)
    print('\n')
    plt.figure(figsize=(10,40))
    plt.subplot(911)
    plt.title(name)
    plt.plot(false_positive_rate,true_positive_rate,label='AUC = %0.2f'% roc_auc)
    plt.plot([0,1],[0,1],'r--')
    plt.legend(loc='lower right')
    plt.ylabel('True positive Rate')
    plt.xlabel('False Positive Rate')
    print('\n\n')
# Out:
# LogisticRegression
#
#
# LogisticRegression()
#
#
# Accuracy_score= 0.8789625360230547
#
#
# Cross_Val_Score= 0.8738452716087999
#
#
# roc_auc_score= 0.6950090744101634
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93       290
#            1       0.73      0.42      0.53        57
#
#     accuracy                           0.88       347
#    macro avg       0.81      0.70      0.73       347
# weighted avg       0.87      0.88      0.87       347
#
#
#
# [[281   9]
#  [ 33  24]]
#
#
#
#
#
# GaussianNB
#
#
# GaussianNB()
#
#
# Accuracy_score= 0.829971181556196
#
#
# Cross_Val_Score= 0.8183348972995518
#
#
# roc_auc_score= 0.7079854809437386
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90       290
#            1       0.48      0.53      0.50        57
#
#     accuracy                           0.83       347
# ...

# %%
result = pd.DataFrame({'Model':Model,'Accuracy_score': score,'cross_val_score':CVS,'Roc_auc_curve':rocscore})
result
# Out:
#                         Model  Accuracy_score  cross_val_score  Roc_auc_curve
# 0          LogisticRegression       87.896254        87.384527      69.500907
# 1                  GaussianNB       82.997118        81.833490      70.798548
# 2      RandomForestClassifier       85.302594        85.653738      57.377495
# 3  GradientBoostingClassifier       86.455331        86.447711      63.705384
# 4        KNeighborsClassifier       85.878963        84.716401      57.017544
# 5                         SVC       86.743516        86.086957      62.468240
# 6      DecisionTreeClassifier       79.538905        78.010114      63.091349
# 7          AdaBoostClassifier       87.608069        87.458034      70.738052

# %% [markdown]
# From the above table we can see that Logistic Regression gives us best. Additionally, Roc_auc score is Heighest among all the Models. We can see that the accuracy score for logistic Regression Model is also Good.
#
# So considering all parameters like roc_auc score and accuracy score,cross val score our final model will be Logistic Regression.

# %% [markdown]
# ## Hyperparameter Tuneing using GridSearchCV

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=60,test_size=.20,stratify=y)

x_train_s,y_train_s=(x_train,y_train)

param={'penalty':['l2','l1'],'C':[.0001,.001,.01,1,10],'solver':['liblinear','saga']}

grid=GridSearchCV(estimator=lr,param_grid=param,scoring='accuracy',n_jobs=-1)

grid.fit(x_train_s,y_train_s)

grid.best_params_
# Out:
# {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}

# %%
lr_final=LogisticRegression(C=0.01,penalty='l2',solver='liblinear')
lr_final.fit(x_train_s,y_train_s)
pred=lr_final.predict(x_test)

# %%
print('Final Accuracy_score :',accuracy_score(pred,y_test))
# Out:
# Final Accuracy_score : 0.8920863309352518

# %% [markdown]
# So we can see that Acuuracy Score has improved to 89.20

# %% [markdown]
# # Saving The Model

# %%
import joblib
joblib.dump(lr_final,'HR Attrition_lr.pkl')
# Out:
# ['HR Attrition_lr.pkl']
